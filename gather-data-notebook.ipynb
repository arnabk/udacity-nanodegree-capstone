# %% [markdown]
# # Download stock list

# %%
pip install datapackage yfinance lxml pandas_datareader html5lib ta-lib
# Out:
# Requirement already satisfied: datapackage in /root/anaconda3/envs/py37/lib/python3.7/site-packages (1.11.0)
# Requirement already satisfied: yfinance in /root/anaconda3/envs/py37/lib/python3.7/site-packages (0.1.54)
# Requirement already satisfied: lxml in /root/anaconda3/envs/py37/lib/python3.7/site-packages (4.5.0)
# Requirement already satisfied: pandas_datareader in /root/anaconda3/envs/py37/lib/python3.7/site-packages (0.8.1)
# Requirement already satisfied: html5lib in /root/anaconda3/envs/py37/lib/python3.7/site-packages (1.0.1)
# Requirement already satisfied: ta-lib in /root/anaconda3/envs/py37/lib/python3.7/site-packages (0.4.17)
# Requirement already satisfied: click>=6.7 in /root/anaconda3/envs/py37/lib/python3.7/site-packages (from datapackage) (7.0)
# Requirement already satisfied: requests>=2.8 in /root/anaconda3/envs/py37/lib/python3.7/site-packages (from datapackage) (2.22.0)
# Requirement already satisfied: jsonschema>=2.5 in /root/anaconda3/envs/py37/lib/python3.7/site-packages (from datapackage) (3.2.0)
# Requirement already satisfied: unicodecsv>=0.14 in /root/anaconda3/envs/py37/lib/python3.7/site-packages (from datapackage) (0.14.1)
# Requirement already satisfied: tabulator>=1.29 in /root/anaconda3/envs/py37/lib/python3.7/site-packages (from datapackage) (1.33.0)
# Requirement already satisfied: tableschema>=1.12.1 in /root/anaconda3/envs/py37/lib/python3.7/site-packages (from datapackage) (1.12.3)
# Requirement already satisfied: cchardet>=1.0 in /root/anaconda3/envs/py37/lib/python3.7/site-packages (from datapackage) (2.1.5)
# Requirement already satisfied: jsonpointer>=1.10 in /root/anaconda3/envs/py37/lib/python3.7/site-packages (from datapackage) (2.0)
# Requirement already satisfied: six>=1.10 in /root/anaconda3/envs/py37/lib/python3.7/site-packages (from datapackage) (1.14.0)
# Requirement already satisfied: numpy>=1.15 in /root/anaconda3/envs/py37/lib/python3.7/site-packages (from yfinance) (1.18.1)
# Requirement already satisfied: multitasking>=0.0.7 in /root/anaconda3/envs/py37/lib/python3.7/site-packages (from yfinance) (0.0.9)
# Requirement already satisfied: pandas>=0.24 in /root/anaconda3/envs/py37/lib/python3.7/site-packages (from yfinance) (0.25.3)
# Requirement already satisfied: webencodings in /root/anaconda3/envs/py37/lib/python3.7/site-packages (from html5lib) (0.5.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /root/anaconda3/envs/py37/lib/python3.7/site-packages (from requests>=2.8->datapackage) (1.25.7)
# Requirement already satisfied: certifi>=2017.4.17 in /root/anaconda3/envs/py37/lib/python3.7/site-packages (from requests>=2.8->datapackage) (2019.11.28)
# Requirement already satisfied: idna<2.9,>=2.5 in /root/anaconda3/envs/py37/lib/python3.7/site-packages (from requests>=2.8->datapackage) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /root/anaconda3/envs/py37/lib/python3.7/site-packages (from requests>=2.8->datapackage) (3.0.4)
# Requirement already satisfied: setuptools in /root/anaconda3/envs/py37/lib/python3.7/site-packages (from jsonschema>=2.5->datapackage) (44.0.0.post20200106)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /root/anaconda3/envs/py37/lib/python3.7/site-packages (from jsonschema>=2.5->datapackage) (1.4.0)
# Requirement already satisfied: attrs>=17.4.0 in /root/anaconda3/envs/py37/lib/python3.7/site-packages (from jsonschema>=2.5->datapackage) (19.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /root/anaconda3/envs/py37/lib/python3.7/site-packages (from jsonschema>=2.5->datapackage) (0.15.7)
# Requirement already satisfied: openpyxl>=2.6 in /root/anaconda3/envs/py37/lib/python3.7/site-packages (from tabulator>=1.29->datapackage) (3.0.3)
# Requirement already satisfied: boto3>=1.9 in /root/anaconda3/envs/py37/lib/python3.7/site-packages (from tabulator>=1.29->datapackage) (1.11.5)
# Requirement already satisfied: linear-tsv>=1.0 in /root/anaconda3/envs/py37/lib/python3.7/site-packages (from tabulator>=1.29->datapackage) (1.1.0)
# Requirement already satisfied: xlrd>=1.0 in /root/anaconda3/envs/py37/lib/python3.7/site-packages (from tabulator>=1.29->datapackage) (1.2.0)
# Requirement already satisfied: sqlalchemy>=0.9.6 in /root/anaconda3/envs/py37/lib/python3.7/site-packages (from tabulator>=1.29->datapackage) (1.3.13)
# Requirement already satisfied: ijson>=2.5 in /root/anaconda3/envs/py37/lib/python3.7/site-packages (from tabulator>=1.29->datapackage) (2.6.0)
# Requirement already satisfied: jsonlines>=1.1 in /root/anaconda3/envs/py37/lib/python3.7/site-packages (from tabulator>=1.29->datapackage) (1.2.0)
# Requirement already satisfied: rfc3986>=1.1.0 in /root/anaconda3/envs/py37/lib/python3.7/site-packages (from tableschema>=1.12.1->datapackage) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.4 in /root/anaconda3/envs/py37/lib/python3.7/site-packages (from tableschema>=1.12.1->datapackage) (2.8.1)
# Requirement already satisfied: isodate>=0.5.4 in /root/anaconda3/envs/py37/lib/python3.7/site-packages (from tableschema>=1.12.1->datapackage) (0.6.0)
# Requirement already satisfied: pytz>=2017.2 in /root/anaconda3/envs/py37/lib/python3.7/site-packages (from pandas>=0.24->yfinance) (2019.3)
# Requirement already satisfied: zipp>=0.5 in /root/anaconda3/envs/py37/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->jsonschema>=2.5->datapackage) (1.0.0)
# Requirement already satisfied: jdcal in /root/anaconda3/envs/py37/lib/python3.7/site-packages (from openpyxl>=2.6->tabulator>=1.29->datapackage) (1.4.1)
# Requirement already satisfied: et-xmlfile in /root/anaconda3/envs/py37/lib/python3.7/site-packages (from openpyxl>=2.6->tabulator>=1.29->datapackage) (1.0.1)
# Requirement already satisfied: botocore<1.15.0,>=1.14.5 in /root/anaconda3/envs/py37/lib/python3.7/site-packages (from boto3>=1.9->tabulator>=1.29->datapackage) (1.14.7)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /root/anaconda3/envs/py37/lib/python3.7/site-packages (from boto3>=1.9->tabulator>=1.29->datapackage) (0.9.4)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /root/anaconda3/envs/py37/lib/python3.7/site-packages (from boto3>=1.9->tabulator>=1.29->datapackage) (0.3.1)
# Requirement already satisfied: more-itertools in /root/anaconda3/envs/py37/lib/python3.7/site-packages (from zipp>=0.5->importlib-metadata; python_version < "3.8"->jsonschema>=2.5->datapackage) (8.1.0)
# Requirement already satisfied: docutils<0.16,>=0.10 in /root/anaconda3/envs/py37/lib/python3.7/site-packages (from botocore<1.15.0,>=1.14.5->boto3>=1.9->tabulator>=1.29->datapackage) (0.15.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from datapackage import Package
package = Package('https://datahub.io/core/nyse-other-listings/datapackage.json')
package.resource_names
# Out:
# ['validation_report',
#  'nyse-listed_csv',
#  'other-listed_csv',
#  'nyse-listed_json',
#  'other-listed_json',
#  'nyse-other-listings_zip',
#  'nyse-listed_csv_preview',
#  'other-listed_csv_preview',
#  'nyse-listed',
#  'other-listed']

# %%
import pandas as pd
from os import path
import yfinance as yf

file_name = 'data/nyse.csv'

# If we don't have data locally, download from remote source
if not path.exists(file_name):
    # filter data file
    filter_fn = lambda resource: resource.name == 'nyse-listed_csv'
    resource = list(filter(filter_fn, package.resources))[0]
    df = pd.DataFrame.from_dict(resource.read())
    df.columns=["Symbol", "Description"]
    df.to_csv(file_name, index=False)
    
stocks_df = pd.read_csv(file_name)
stocks_df.index = stocks_df['Symbol'].values
print(stocks_df.head())
print(stocks_df.tail())
print(stocks_df.shape)
# Out:
#      Symbol                                        Description
# A         A            Agilent Technologies, Inc. Common Stock
# AA       AA                            Alcoa Inc. Common Stock
# AA$B   AA$B  Alcoa Inc. Depository Shares Representing 1/10...
# AAC     AAC                    AAC Holdings, Inc. Common Stock
# AAN     AAN                         Aaron's, Inc. Common Stock
#      Symbol                                        Description
# ZPIN   ZPIN  Zhaopin Limited American Depositary Shares, ea...
# ZQK     ZQK                      Quiksilver, Inc. Common Stock
# ZTR     ZTR   Zweig Total Return Fund, Inc. (The) Common Stock
# ZTS     ZTS                   Zoetis Inc. Class A Common Stock
# ZX       ZX  China Zenix Auto International Limited America...
# (3298, 2)

# %%
import yfinance as yf
import numpy as np
import sys

file_name_with_vol = file_name.replace(".csv", "-volume.csv")

# If we don't have data locally, download from remote source
if not path.exists(file_name_with_vol):

    tickers = []
    batch_counter = 0
    batch_size = 100
    total_symbols = stocks_df.shape[0]
    stocks_vol_df = pd.DataFrame(stocks_df)
    
    for stock in stocks_df['Symbol'].values:
        # We are going to download 100 ticker information at a time
        if len(tickers) >= 100 or (batch_counter * batch_size + len(tickers)) >= total_symbols:
            
            batch_counter = batch_counter + 1
            
            # Download information
            tickers_data = yf.Tickers(' '.join(tickers)).tickers
            print('Batch ', batch_counter, 'with', len(tickers_data), ' tickers')

            # Store last known volume
            for ticker in tickers:
                try:
                    print('Processing yF:', getattr(tickers_data, ticker), ', Ticker name:', ticker)
                    stocks_vol_df.loc[ticker, 'Last Volume'] = getattr(tickers_data, ticker).info['averageVolume']
                except:
                    # It is possible that some of th tickets do not have the information we are looking for
                    # and they may throw exception while processing
                    print('Filed to process', ticker, sys.exc_info())

            print('Downloaded volume info for', tickers)

            # clear the list for next batch
            tickers = []

        tickers.append(stock)

    stocks_vol_df.to_csv(file_name_with_vol, index=False)

stocks_vol_df = pd.read_csv(file_name_with_vol).dropna()
stocks_vol_df.index = stocks_vol_df['Symbol'].values
print(stocks_vol_df.head())
print(stocks_vol_df.shape)
# Out:
#     Symbol                                        Description  Last Volume
# A        A            Agilent Technologies, Inc. Common Stock    1712146.0
# AA      AA                            Alcoa Inc. Common Stock    4695503.0
# AAP    AAP  Advance Auto Parts Inc Advance Auto Parts Inc W/I    1065904.0
# AAT    AAT           American Assets Trust, Inc. Common Stock     275667.0
# ABB    ABB                               ABB Ltd Common Stock    1777283.0
# (1511, 3)

# %%
# We are going to use stocks with last known volume more than 1,000,000
stocks_vol_df = stocks_vol_df[stocks_vol_df['Last Volume'] >= 1000000]
print(stocks_vol_df.head())
print(stocks_vol_df.shape)
# Out:
#      Symbol                                        Description  Last Volume
# A         A            Agilent Technologies, Inc. Common Stock    1712146.0
# AA       AA                            Alcoa Inc. Common Stock    4695503.0
# AAP     AAP  Advance Auto Parts Inc Advance Auto Parts Inc W/I    1065904.0
# ABB     ABB                               ABB Ltd Common Stock    1777283.0
# ABBV   ABBV                           AbbVie Inc. Common Stock    8004485.0
# (455, 3)

# %%
start_date = '2010-01-01'
end_date = '2019-12-31'
data_folder = 'data/'

for ticker in stocks_vol_df.index.values:
    f_name = data_folder + ticker + '.csv'
    if not path.exists(f_name):
        data = yf.download(ticker, start=start_date, end=end_date)
        data.to_csv(f_name)
    else:
        print('Data exists for:', ticker)
# Out:
# Data exists for: A
# Data exists for: AA
# Data exists for: AAP
# Data exists for: ABB
# Data exists for: ABBV
# Data exists for: ABEV
# Data exists for: ABR
# Data exists for: ABT
# Data exists for: ACM
# Data exists for: ADM
# Data exists for: ADPT
# Data exists for: ADT
# Data exists for: AEE
# Data exists for: AEG
# Data exists for: AEM
# Data exists for: AEP
# Data exists for: AES
# Data exists for: AFL
# Data exists for: AGI
# Data exists for: AKS
# Data exists for: ALB
# Data exists for: ALL
# Data exists for: ALLY
# Data exists for: ALSN
# Data exists for: AM
# Data exists for: AMC
# Data exists for: AME
# Data exists for: AMH
# Data exists for: AMT
# Data exists for: AMX
# Data exists for: ANF
# Data exists for: AOS
# Data exists for: APA
# Data exists for: APD
# Data exists for: AR
# Data exists for: ARI
# Data exists for: ARMK
# Data exists for: ASB
# Data exists for: AUY
# Data exists for: AVP
# Data exists for: AXL
# Data exists for: AXP
# Data exists for: AXTA
# Data exists for: AZN
# Data exists for: BA
# Data exists for: BABA
# Data exists for: BAC
# Data exists for: BAH
# Data exists for: BAS
# Data exists for: BAX
# Data exists for: BBT
# Data exists for: BBY
# Data exists for: BCS
# Data exists for: BDX
# Data exists for: BEN
# Data exists for: BERY
# Data exists for: BGG
# Data exists for: BGS
# Data exists for: BHP
# Data exists for: BIG
# Data exists for: BKD
# Data exists for: BLL
# Data exists for: BP
# Data exists for: BPY
# Data exists for: BRFS
# Data exists for: BRO
# Data exists for: BRX
# Data exists for: BSBR
# Data exists for: BSX
# Data exists for: BTE
# Data exists for: BTU
# Data exists for: BUD
# Data exists for: BVN
# Data exists for: BWA
# Data exists for: BX
# Data exists for: CAG
# Data exists for: CAT
# Data exists for: CBL
# Data exists for: CBS
# Data exists for: CCC
# Data exists for: CCI
# Data exists for: CCJ
# Data exists for: CCO
# Data exists for: CF
# Data exists for: CFG
# Data exists for: CFX
# Data exists for: CHD
# Data exists for: CHGG
# Data exists for: CHK
# Data exists for: CHL
# Data exists for: CHS
# Data exists for: CI
# Data exists for: CIG
# Data exists for: CIT
# Data exists for: CL
# Data exists for: CLR
# Data exists for: CMA
# Data exists for: CMC
# Data exists for: CMI
# Data exists for: CMS
# Data exists for: CNC
# Data exists for: CNHI
# Data exists for: CNK
# Data exists for: CNO
# Data exists for: CNP
# Data exists for: CNQ
# Data exists for: CNX
# Data exists for: COF
# Data exists for: COG
# Data exists for: COP
# Data exists for: COT
# Data exists for: COTY
# Data exists for: COUP
# Data exists for: CPB
# Data exists for: CPE
# Data exists for: CPG
# Data exists for: CS
# Data exists for: CSTM
# Data exists for: CSX
# Data exists for: CUBE
# Data exists for: CVE
# Data exists for: CVS
# Data exists for: CX
# Data exists for: CXO
# Data exists for: CXW
# Data exists for: CYH
# Data exists for: D
# Data exists for: DAL
# Data exists for: DAN
# Data exists for: DAR
# Data exists for: DB
# Data exists for: DBD
# Data exists for: DE
# Data exists for: DFS
# Data exists for: DG
# Data exists for: DHI
# Data exists for: DIS
# Data exists for: DKS
# Data exists for: DLPH
# Data exists for: DLR
# Data exists for: DNOW
# Data exists for: DO
# Data exists for: DOC
# Data exists for: DOW
# Data exists for: DPLO
# Data exists for: DRH
# Data exists for: DRI
# Data exists for: DTE
# Data exists for: DVA
# Data exists for: ECA
# Data exists for: ECL
# Data exists for: ED
# Data exists for: EDU
# Data exists for: EIX
# Data exists for: EL
# Data exists for: EMN
# Data exists for: EMR
# Data exists for: ENB
# Data exists for: ENBL
# Data exists for: ENLC
# Data exists for: EOG
# Data exists for: EPD
# Data exists for: EQM
# Data exists for: EQR
# Data exists for: EQT
# Data exists for: ERF
# Data exists for: EROS
# Data exists for: ESI
# Data exists for: EW
# Data exists for: EXC
# Data exists for: EXK
# Data exists for: EXPR
# Data exists for: FBHS
# Data exists for: FCAU
# Data exists for: FCX
# Data exists for: FE
# Data exists for: FHN
# Data exists for: FIS
# Data exists for: FL
# Data exists for: FLO
# Data exists for: FLR
# Data exists for: FNB
# Data exists for: FNF
# Data exists for: FRC
# Data exists for: FSM
# Data exists for: FTI
# Data exists for: G
# Data exists for: GCI
# Data exists for: GD
# Data exists for: GE
# Data exists for: GES
# Data exists for: GFI
# Data exists for: GGB
# Data exists for: GIS
# Data exists for: GLW
# Data exists for: GM
# Data exists for: GNW
# Data exists for: GPN
# Data exists for: GPS
# Data exists for: GRUB
# Data exists for: GS
# Data exists for: HAL
# Data exists for: HBI
# Data exists for: HCA
# Data exists for: HD
# Data exists for: HDB
# Data exists for: HIG
# Data exists for: HL
# Data exists for: HOG
# Data exists for: HP
# Data exists for: HPQ
# Data exists for: HRB
# Data exists for: HRL
# Data exists for: HUN
# Data exists for: I
# Data exists for: IAG
# Data exists for: IBM
# Data exists for: IBN
# Data exists for: ICE
# Data exists for: IFF
# Data exists for: IGT
# Data exists for: INFY
# Data exists for: ING
# Data exists for: INXN
# Data exists for: IP
# Data exists for: IPG
# Data exists for: IRM
# Data exists for: ITW
# Data exists for: IVR
# Data exists for: IVZ
# Data exists for: JBL
# Data exists for: JCI
# Data exists for: JCP
# Data exists for: JEC
# Data exists for: JNJ
# Data exists for: JNPR
# Data exists for: JWN
# Data exists for: K
# Data exists for: KAR
# Data exists for: KBR
# Data exists for: KEG
# Data exists for: KEY
# Data exists for: KEYS
# Data exists for: KIM
# Data exists for: KKR
# Data exists for: KMB
# Data exists for: KMI
# Data exists for: KMX
# Data exists for: KNX
# Data exists for: KO
# Data exists for: KOS
# Data exists for: KR
# Data exists for: KSS
# Data exists for: KYN
# Data exists for: LB
# Data exists for: LCI
# Data exists for: LEG
# Data exists for: LEN
# Data exists for: LLY
# Data exists for: LMT
# Data exists for: LNC
# Data exists for: LNT
# Data exists for: LOW
# Data exists for: LPI
# Data exists for: LPT
# Data exists for: LPX
# Data exists for: LUV
# Data exists for: LVS
# Data exists for: LYB
# Data exists for: LYG
# Data exists for: MA
# Data exists for: MAC
# Data exists for: MAS
# Data exists for: MBT
# Data exists for: MCD
# Data exists for: MD
# Data exists for: MDP
# Data exists for: MDT
# Data exists for: MDU
# Data exists for: MET
# Data exists for: MFC
# Data exists for: MGM
# Data exists for: MMC
# Data exists for: MMP
# Data exists for: MNK
# Data exists for: MO
# Data exists for: MOS
# Data exists for: MPC
# Data exists for: MPLX
# Data exists for: MPW
# Data exists for: MRO
# Data exists for: MTDR
# Data exists for: MTG
# Data exists for: MUR
# Data exists for: MUX
# Data exists for: NAT
# Data exists for: NE
# Data exists for: NEM
# Data exists for: NEWM
# Data exists for: NGL
# Data exists for: NIO
# Data exists for: NKE
# Data exists for: NLSN
# Data exists for: NLY
# Data exists for: NOK
# Data exists for: NOV
# Data exists for: NOW
# Data exists for: NRG
# Data exists for: NSC
# Data exists for: NUE
# Data exists for: NVO
# Data exists for: NVS
# Data exists for: NYCB
# Data exists for: NYT
# Data exists for: O
# Data exists for: OAS
# Data exists for: OC
# Data exists for: OGE
# Data exists for: OHI
# Data exists for: OI
# Data exists for: OII
# Data exists for: OLN
# Data exists for: OPK
# Data exists for: ORCL
# Data exists for: ORI
# Data exists for: OXY
# Data exists for: PAA
# Data exists for: PANW
# Data exists for: PBF
# Data exists for: PBI
# Data exists for: PBR
# Data exists for: PBYI
# Data exists for: PCG
# Data exists for: PE
# Data exists for: PEB
# Data exists for: PEI
# Data exists for: PEP
# Data exists for: PFE
# Data exists for: PFG
# Data exists for: PG
# Data exists for: PGR
# Data exists for: PGRE
# Data exists for: PLD
# Data exists for: PM
# Data exists for: PMT
# Data exists for: PNC
# Data exists for: PPG
# Data exists for: PRGO
# Data exists for: PRU
# Data exists for: PSX
# Data exists for: PVG
# Data exists for: PWR
# Data exists for: QEP
# Data exists for: QSR
# Data exists for: RBS
# Data exists for: RCL
# Data exists for: RES
# Data exists for: RF
# Data exists for: RH
# Data exists for: RLGY
# Data exists for: RLJ
# Data exists for: RNG
# Data exists for: ROL
# Data exists for: ROYT
# Data exists for: RPAI
# Data exists for: RSG
# Data exists for: RTN
# Data exists for: RUBI
# Data exists for: S
# Data exists for: SBGL
# Data exists for: SBH
# Data exists for: SBS
# Data exists for: SCHW
# Data exists for: SDRL
# Data exists for: SE
# Data exists for: SEAS
# Data exists for: SEMG
# Data exists for: SERV
# Data exists for: SHO
# Data exists for: SID
# Data exists for: SIX
# Data exists for: SKT
# Data exists for: SKX
# Data exists for: SLB
# Data exists for: SLCA
# Data exists for: SM
# Data exists for: SNH
# Data exists for: SNY
# Data exists for: SO
# Data exists for: SPR
# Data exists for: SRE
# Data exists for: SSI
# Data exists for: STAG
# Data exists for: STAY
# Data exists for: STI
# Data exists for: STOR
# Data exists for: STWD
# Data exists for: SU
# Data exists for: SWK
# Data exists for: SWN
# Data exists for: SXC
# Data exists for: SYF
# Data exists for: SYK
# Data exists for: SYY
# Data exists for: T
# Data exists for: TAL
# Data exists for: TD
# Data exists for: TDC
# Data exists for: TEN
# Data exists for: TER
# Data exists for: TEVA
# Data exists for: TIF
# Data exists for: TJX
# Data exists for: TMO
# Data exists for: TMUS
# Data exists for: TOL
# Data exists for: TOT
# Data exists for: TPH
# Data exists for: TRGP
# Data exists for: TRN
# Data exists for: TROX
# Data exists for: TRP
# Data exists for: TS
# Data exists for: TSM
# Data exists for: TSN
# Data exists for: TTM
# Data exists for: TUP
# Data exists for: TV
# Data exists for: TWTR
# Data exists for: TXT
# Data exists for: UA
# Data exists for: UBS
# Data exists for: UDR
# Data exists for: UGI
# Data exists for: UGP
# Data exists for: UNM
# Data exists for: UNP
# Data exists for: UNT
# Data exists for: UPS
# Data exists for: URI
# Data exists for: UTX
# Data exists for: V
# Data exists for: VEEV
# Data exists for: VET
# Data exists for: VFC
# Data exists for: VG
# Data exists for: VIPS
# Data exists for: VLY
# Data exists for: VMW
# Data exists for: VVR
# Data exists for: W
# Data exists for: WAB
# Data exists for: WDAY
# Data exists for: WEC
# Data exists for: WES

# %%
# Check amount of data downloaded
# !du -h ./data
# Out:
# 0	./data/.ipynb_checkpoints
# 111M	./data

# %%
stocks_vol_df['Last Volume'].describe()
# Out:
# count    4.550000e+02
# mean     4.059946e+06
# std      6.971949e+06
# min      1.004216e+06
# 25%      1.422709e+06
# 50%      2.142141e+06
# 75%      4.032960e+06
# max      8.536380e+07
# Name: Last Volume, dtype: float64

# %%
import talib

# Change window
N = 10

for ticker in stocks_vol_df.index.values:
    stock_price_df = pd.read_csv(data_folder + ticker + '.csv')
    
    # Calculate changes
    for index in range(1, N + 1):
        stock_price_df['N - ' + str(index)] = stock_price_df['Adj Close'] - stock_price_df['Adj Close'].shift(index)
    
    # Create label
    stock_price_df['Label'] = stock_price_df['N - 1'].shift(-1)

    # calculate indicators
    stock_price_df['TRIMA'] = talib.TRIMA(stock_price_df['Close'])
    stock_price_df['SAR'] = talib.SAR(stock_price_df['High'], stock_price_df['Low'])
    
    macd, macdsignal, macdhist = talib.MACD(stock_price_df['Close'])
    stock_price_df['MACD-main'] = macd
    stock_price_df['MACD-signal'] = macdsignal
    stock_price_df['MACD-hist'] = macdhist
    
    stock_price_df['RSI'] = talib.RSI(stock_price_df['Close'])
    
    slowk, slowd = talib.STOCH(stock_price_df['High'], stock_price_df['Low'], stock_price_df['Close'])
    stock_price_df['STOCH-k'] = slowk
    stock_price_df['STOCH-d'] = slowd
    
    stock_price_df['AD'] = talib.AD(stock_price_df['High'], stock_price_df['Low'], stock_price_df['Close'], stock_price_df['Volume'])
    stock_price_df['ATR'] = talib.ATR(stock_price_df['High'], stock_price_df['Low'], stock_price_df['Close'])
    
    # save
    stock_price_df.to_pickle(data_folder + ticker + '.pkl')
    print('Saved', data_folder + ticker + '.pkl')
# Out:
# Saved data/A.pkl
# Saved data/AA.pkl
# Saved data/AAP.pkl
# Saved data/ABB.pkl
# Saved data/ABBV.pkl
# Saved data/ABEV.pkl
# Saved data/ABR.pkl
# Saved data/ABT.pkl
# Saved data/ACM.pkl
# Saved data/ADM.pkl
# Saved data/ADPT.pkl
# Saved data/ADT.pkl
# Saved data/AEE.pkl
# Saved data/AEG.pkl
# Saved data/AEM.pkl
# Saved data/AEP.pkl
# Saved data/AES.pkl
# Saved data/AFL.pkl
# Saved data/AGI.pkl
# Saved data/AKS.pkl
# Saved data/ALB.pkl
# Saved data/ALL.pkl
# Saved data/ALLY.pkl
# Saved data/ALSN.pkl
# Saved data/AM.pkl
# Saved data/AMC.pkl
# Saved data/AME.pkl
# Saved data/AMH.pkl
# Saved data/AMT.pkl
# Saved data/AMX.pkl
# Saved data/ANF.pkl
# Saved data/AOS.pkl
# Saved data/APA.pkl
# Saved data/APD.pkl
# Saved data/AR.pkl
# Saved data/ARI.pkl
# Saved data/ARMK.pkl
# Saved data/ASB.pkl
# Saved data/AUY.pkl
# Saved data/AVP.pkl
# Saved data/AXL.pkl
# Saved data/AXP.pkl
# Saved data/AXTA.pkl
# Saved data/AZN.pkl
# Saved data/BA.pkl
# Saved data/BABA.pkl
# Saved data/BAC.pkl
# Saved data/BAH.pkl
# Saved data/BAS.pkl
# Saved data/BAX.pkl
# Saved data/BBT.pkl
# Saved data/BBY.pkl
# Saved data/BCS.pkl
# Saved data/BDX.pkl
# Saved data/BEN.pkl
# Saved data/BERY.pkl
# Saved data/BGG.pkl
# Saved data/BGS.pkl
# Saved data/BHP.pkl
# Saved data/BIG.pkl
# Saved data/BKD.pkl
# Saved data/BLL.pkl
# Saved data/BP.pkl
# Saved data/BPY.pkl
# Saved data/BRFS.pkl
# Saved data/BRO.pkl
# Saved data/BRX.pkl
# Saved data/BSBR.pkl
# Saved data/BSX.pkl
# Saved data/BTE.pkl
# Saved data/BTU.pkl
# Saved data/BUD.pkl
# Saved data/BVN.pkl
# Saved data/BWA.pkl
# Saved data/BX.pkl
# Saved data/CAG.pkl
# Saved data/CAT.pkl
# Saved data/CBL.pkl
# Saved data/CBS.pkl
# Saved data/CCC.pkl
# Saved data/CCI.pkl
# Saved data/CCJ.pkl
# Saved data/CCO.pkl
# Saved data/CF.pkl
# Saved data/CFG.pkl
# Saved data/CFX.pkl
# Saved data/CHD.pkl
# Saved data/CHGG.pkl
# Saved data/CHK.pkl
# Saved data/CHL.pkl
# Saved data/CHS.pkl
# Saved data/CI.pkl
# Saved data/CIG.pkl
# Saved data/CIT.pkl
# Saved data/CL.pkl
# Saved data/CLR.pkl
# Saved data/CMA.pkl
# Saved data/CMC.pkl
# Saved data/CMI.pkl
# Saved data/CMS.pkl
# Saved data/CNC.pkl
# Saved data/CNHI.pkl
# Saved data/CNK.pkl
# Saved data/CNO.pkl
# Saved data/CNP.pkl
# Saved data/CNQ.pkl
# Saved data/CNX.pkl
# Saved data/COF.pkl
# Saved data/COG.pkl
# Saved data/COP.pkl
# Saved data/COT.pkl
# Saved data/COTY.pkl
# Saved data/COUP.pkl
# Saved data/CPB.pkl
# Saved data/CPE.pkl
# Saved data/CPG.pkl
# Saved data/CS.pkl
# Saved data/CSTM.pkl
# Saved data/CSX.pkl
# Saved data/CUBE.pkl
# Saved data/CVE.pkl
# Saved data/CVS.pkl
# Saved data/CX.pkl
# Saved data/CXO.pkl
# Saved data/CXW.pkl
# Saved data/CYH.pkl
# Saved data/D.pkl
# Saved data/DAL.pkl
# Saved data/DAN.pkl
# Saved data/DAR.pkl
# Saved data/DB.pkl
# Saved data/DBD.pkl
# Saved data/DE.pkl
# Saved data/DFS.pkl
# Saved data/DG.pkl
# Saved data/DHI.pkl
# Saved data/DIS.pkl
# Saved data/DKS.pkl
# Saved data/DLPH.pkl
# Saved data/DLR.pkl
# Saved data/DNOW.pkl
# Saved data/DO.pkl
# Saved data/DOC.pkl
# Saved data/DOW.pkl
# Saved data/DPLO.pkl
# Saved data/DRH.pkl
# Saved data/DRI.pkl
# Saved data/DTE.pkl
# Saved data/DVA.pkl
# Saved data/ECA.pkl
# Saved data/ECL.pkl
# Saved data/ED.pkl
# Saved data/EDU.pkl
# Saved data/EIX.pkl
# Saved data/EL.pkl
# Saved data/EMN.pkl
# Saved data/EMR.pkl
# Saved data/ENB.pkl
# Saved data/ENBL.pkl
# Saved data/ENLC.pkl
# Saved data/EOG.pkl
# Saved data/EPD.pkl
# Saved data/EQM.pkl
# Saved data/EQR.pkl
# Saved data/EQT.pkl
# Saved data/ERF.pkl
# Saved data/EROS.pkl
# Saved data/ESI.pkl
# Saved data/EW.pkl
# Saved data/EXC.pkl
# Saved data/EXK.pkl
# Saved data/EXPR.pkl
# Saved data/FBHS.pkl
# Saved data/FCAU.pkl
# Saved data/FCX.pkl
# Saved data/FE.pkl
# Saved data/FHN.pkl
# Saved data/FIS.pkl
# Saved data/FL.pkl
# Saved data/FLO.pkl
# Saved data/FLR.pkl
# Saved data/FNB.pkl
# Saved data/FNF.pkl
# Saved data/FRC.pkl
# Saved data/FSM.pkl
# Saved data/FTI.pkl
# Saved data/G.pkl
# Saved data/GCI.pkl
# Saved data/GD.pkl
# Saved data/GE.pkl
# Saved data/GES.pkl
# Saved data/GFI.pkl
# Saved data/GGB.pkl
# Saved data/GIS.pkl
# Saved data/GLW.pkl
# Saved data/GM.pkl
# Saved data/GNW.pkl
# Saved data/GPN.pkl
# Saved data/GPS.pkl
# Saved data/GRUB.pkl
# Saved data/GS.pkl
# Saved data/HAL.pkl
# Saved data/HBI.pkl
# Saved data/HCA.pkl
# Saved data/HD.pkl
# Saved data/HDB.pkl
# Saved data/HIG.pkl
# Saved data/HL.pkl
# Saved data/HOG.pkl
# Saved data/HP.pkl
# Saved data/HPQ.pkl
# Saved data/HRB.pkl
# Saved data/HRL.pkl
# Saved data/HUN.pkl
# Saved data/I.pkl
# Saved data/IAG.pkl
# Saved data/IBM.pkl
# Saved data/IBN.pkl
# Saved data/ICE.pkl
# Saved data/IFF.pkl
# Saved data/IGT.pkl
# Saved data/INFY.pkl
# Saved data/ING.pkl
# Saved data/INXN.pkl
# Saved data/IP.pkl
# Saved data/IPG.pkl
# Saved data/IRM.pkl
# Saved data/ITW.pkl
# Saved data/IVR.pkl
# Saved data/IVZ.pkl
# Saved data/JBL.pkl
# Saved data/JCI.pkl
# Saved data/JCP.pkl
# Saved data/JEC.pkl
# Saved data/JNJ.pkl
# Saved data/JNPR.pkl
# Saved data/JWN.pkl
# Saved data/K.pkl
# Saved data/KAR.pkl
# Saved data/KBR.pkl
# Saved data/KEG.pkl
# Saved data/KEY.pkl
# Saved data/KEYS.pkl
# Saved data/KIM.pkl
# Saved data/KKR.pkl
# Saved data/KMB.pkl
# Saved data/KMI.pkl
# Saved data/KMX.pkl
# Saved data/KNX.pkl
# Saved data/KO.pkl
# Saved data/KOS.pkl
# Saved data/KR.pkl
# Saved data/KSS.pkl
# Saved data/KYN.pkl
# Saved data/LB.pkl
# Saved data/LCI.pkl
# Saved data/LEG.pkl
# Saved data/LEN.pkl
# Saved data/LLY.pkl
# Saved data/LMT.pkl
# Saved data/LNC.pkl
# Saved data/LNT.pkl
# Saved data/LOW.pkl
# Saved data/LPI.pkl
# Saved data/LPT.pkl
# Saved data/LPX.pkl
# Saved data/LUV.pkl
# Saved data/LVS.pkl
# Saved data/LYB.pkl
# Saved data/LYG.pkl
# Saved data/MA.pkl
# Saved data/MAC.pkl
# Saved data/MAS.pkl
# Saved data/MBT.pkl
# Saved data/MCD.pkl
# Saved data/MD.pkl
# Saved data/MDP.pkl
# Saved data/MDT.pkl
# Saved data/MDU.pkl
# Saved data/MET.pkl
# Saved data/MFC.pkl
# Saved data/MGM.pkl
# Saved data/MMC.pkl
# Saved data/MMP.pkl
# Saved data/MNK.pkl
# Saved data/MO.pkl
# Saved data/MOS.pkl
# Saved data/MPC.pkl
# Saved data/MPLX.pkl
# Saved data/MPW.pkl
# Saved data/MRO.pkl
# Saved data/MTDR.pkl
# Saved data/MTG.pkl
# Saved data/MUR.pkl
# Saved data/MUX.pkl
# Saved data/NAT.pkl
# Saved data/NE.pkl
# Saved data/NEM.pkl
# Saved data/NEWM.pkl
# Saved data/NGL.pkl
# Saved data/NIO.pkl
# Saved data/NKE.pkl
# Saved data/NLSN.pkl
# Saved data/NLY.pkl
# Saved data/NOK.pkl
# Saved data/NOV.pkl
# Saved data/NOW.pkl
# Saved data/NRG.pkl
# Saved data/NSC.pkl
# Saved data/NUE.pkl
# Saved data/NVO.pkl
# Saved data/NVS.pkl
# Saved data/NYCB.pkl
# Saved data/NYT.pkl
# Saved data/O.pkl
# Saved data/OAS.pkl
# Saved data/OC.pkl
# Saved data/OGE.pkl
# Saved data/OHI.pkl
# Saved data/OI.pkl
# Saved data/OII.pkl
# Saved data/OLN.pkl
# Saved data/OPK.pkl
# Saved data/ORCL.pkl
# Saved data/ORI.pkl
# Saved data/OXY.pkl
# Saved data/PAA.pkl
# Saved data/PANW.pkl
# Saved data/PBF.pkl
# Saved data/PBI.pkl
# Saved data/PBR.pkl
# Saved data/PBYI.pkl
# Saved data/PCG.pkl
# Saved data/PE.pkl
# Saved data/PEB.pkl
# Saved data/PEI.pkl
# Saved data/PEP.pkl
# Saved data/PFE.pkl
# Saved data/PFG.pkl
# Saved data/PG.pkl
# Saved data/PGR.pkl
# Saved data/PGRE.pkl
# Saved data/PLD.pkl
# Saved data/PM.pkl
# Saved data/PMT.pkl
# Saved data/PNC.pkl
# Saved data/PPG.pkl
# Saved data/PRGO.pkl
# Saved data/PRU.pkl
# Saved data/PSX.pkl
# Saved data/PVG.pkl
# Saved data/PWR.pkl
# Saved data/QEP.pkl
# Saved data/QSR.pkl
# Saved data/RBS.pkl
# Saved data/RCL.pkl
# Saved data/RES.pkl
# Saved data/RF.pkl
# Saved data/RH.pkl
# Saved data/RLGY.pkl
# Saved data/RLJ.pkl
# Saved data/RNG.pkl
# Saved data/ROL.pkl
# Saved data/ROYT.pkl
# Saved data/RPAI.pkl
# Saved data/RSG.pkl
# Saved data/RTN.pkl
# Saved data/RUBI.pkl
# Saved data/S.pkl
# Saved data/SBGL.pkl
# Saved data/SBH.pkl
# Saved data/SBS.pkl
# Saved data/SCHW.pkl
# Saved data/SDRL.pkl
# Saved data/SE.pkl
# Saved data/SEAS.pkl
# Saved data/SEMG.pkl
# Saved data/SERV.pkl
# Saved data/SHO.pkl
# Saved data/SID.pkl
# Saved data/SIX.pkl
# Saved data/SKT.pkl
# Saved data/SKX.pkl
# Saved data/SLB.pkl
# Saved data/SLCA.pkl
# Saved data/SM.pkl
# Saved data/SNH.pkl
# Saved data/SNY.pkl
# Saved data/SO.pkl
# Saved data/SPR.pkl
# Saved data/SRE.pkl
# Saved data/SSI.pkl
# Saved data/STAG.pkl
# Saved data/STAY.pkl
# Saved data/STI.pkl
# Saved data/STOR.pkl
# Saved data/STWD.pkl
# Saved data/SU.pkl
# Saved data/SWK.pkl
# Saved data/SWN.pkl
# Saved data/SXC.pkl
# Saved data/SYF.pkl
# Saved data/SYK.pkl
# Saved data/SYY.pkl
# Saved data/T.pkl
# Saved data/TAL.pkl
# Saved data/TD.pkl
# Saved data/TDC.pkl
# Saved data/TEN.pkl
# Saved data/TER.pkl
# Saved data/TEVA.pkl
# Saved data/TIF.pkl
# Saved data/TJX.pkl
# Saved data/TMO.pkl
# Saved data/TMUS.pkl
# Saved data/TOL.pkl
# Saved data/TOT.pkl
# Saved data/TPH.pkl
# Saved data/TRGP.pkl
# Saved data/TRN.pkl
# Saved data/TROX.pkl
# Saved data/TRP.pkl
# Saved data/TS.pkl
# Saved data/TSM.pkl
# Saved data/TSN.pkl
# Saved data/TTM.pkl
# Saved data/TUP.pkl
# Saved data/TV.pkl
# Saved data/TWTR.pkl
# Saved data/TXT.pkl
# Saved data/UA.pkl
# Saved data/UBS.pkl
# Saved data/UDR.pkl
# Saved data/UGI.pkl
# Saved data/UGP.pkl
# Saved data/UNM.pkl
# Saved data/UNP.pkl
# Saved data/UNT.pkl
# Saved data/UPS.pkl
# Saved data/URI.pkl
# Saved data/UTX.pkl
# Saved data/V.pkl
# Saved data/VEEV.pkl
# Saved data/VET.pkl
# Saved data/VFC.pkl
# Saved data/VG.pkl
# Saved data/VIPS.pkl
# Saved data/VLY.pkl
# Saved data/VMW.pkl
# Saved data/VVR.pkl
# Saved data/W.pkl
# Saved data/WAB.pkl
# Saved data/WDAY.pkl
# Saved data/WEC.pkl
# Saved data/WES.pkl

# %%
# Find missing data
